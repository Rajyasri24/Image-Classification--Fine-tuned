# %% [markdown]
# CNN - IMAGE CLASSIFICATION **after increasing the number of epoch**

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
# !git clone https://github.com/mesushan/CNN-for-image-Classification.git
# Out:
# Cloning into 'CNN-for-image-Classification'...
# remote: Enumerating objects: 10026, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 10026 (delta 0), reused 13 (delta 0), pack-reused 10012
# Receiving objects: 100% (10026/10026), 216.96 MiB | 39.24 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Updating files: 100% (10007/10007), done.

# %%
! ls
# Out:
# CNN-for-image-Classification  sample_data

# %%
import tensorflow as tf

# %%
# Initialising the CNN
model = tf.keras.models.Sequential()

# %%
# 32 feature detectors with 3*3 dimensions so the convolution layer compose of 32 feature maps
# 128 by 128 dimensions with colored image(3 channels)  (tensorflow backend)
input_size = (128, 128)
model.add(tf.keras.layers.Convolution2D(32, 3, 3, input_shape = (*input_size, 3), activation = 'relu'))

# %%
# reduce the size of feature maps and therefore reduce the number of nodes in the future fully connected layer (reduce time complexity, less compute intense without losing the performace). 2 by 2 deminsion is the recommended option
model.add(tf.keras.layers.MaxPooling2D(pool_size = (2, 2)))

# %%
model.add(tf.keras.layers.Convolution2D(32, 3, 3, activation = 'relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size = (2, 2)))

# %%
# flatten all the feature maps in the pooling layer into single vector
model.add(tf.keras.layers.Flatten())

# %%
# making classic ann which compose of fully connected layers
# number of nodes in hidden layer (output_dim) (common practice is to take the power of 2)
model.add(tf.keras.layers.Dense(units = 64, activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# %%
# Compiling the CNN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# image augmentation technique to enrich our dataset(training set) without adding more images so get good performance  results with little or no overfitting even with the small amount of images
# used from keras documentation (flow_from_directory method)

from keras.preprocessing.image import ImageDataGenerator
batch_size = 32
# image augmentation part
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# create training set
# wanna get higher accuracy -> inccrease target_size
training_set = train_datagen.flow_from_directory('/content/CNN-for-image-Classification/dataset/training_set',
                                                 target_size = input_size,
                                                 batch_size = batch_size,
                                                 class_mode = 'binary')

# create test set
# wanna get higher accuracy -> inccrease target_size
test_set = test_datagen.flow_from_directory('/content/CNN-for-image-Classification/dataset/test_set',
                                            target_size = input_size,
                                            batch_size = batch_size,
                                            class_mode = 'binary')

# fit the cnn model to the trainig set and testing it on the test set
history=model.fit(training_set,
          steps_per_epoch = 8000/batch_size,
          epochs = 60,
          validation_data = test_set,
          validation_steps = 2000/batch_size)
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Epoch 1/60
# 250/250 [==============================] - 67s 265ms/step - loss: 0.6910 - accuracy: 0.5295 - val_loss: 0.6768 - val_accuracy: 0.6080
# Epoch 2/60
# 250/250 [==============================] - 55s 219ms/step - loss: 0.6655 - accuracy: 0.5993 - val_loss: 0.6580 - val_accuracy: 0.5920
# Epoch 3/60
# 250/250 [==============================] - 53s 213ms/step - loss: 0.6246 - accuracy: 0.6522 - val_loss: 0.5865 - val_accuracy: 0.6960
# Epoch 4/60
# 250/250 [==============================] - 54s 215ms/step - loss: 0.5909 - accuracy: 0.6860 - val_loss: 0.5613 - val_accuracy: 0.7235
# Epoch 5/60
# 250/250 [==============================] - 52s 209ms/step - loss: 0.5748 - accuracy: 0.6935 - val_loss: 0.5558 - val_accuracy: 0.7205
# Epoch 6/60
# 250/250 [==============================] - 52s 207ms/step - loss: 0.5592 - accuracy: 0.7195 - val_loss: 0.5452 - val_accuracy: 0.7275
# Epoch 7/60
# 250/250 [==============================] - 52s 209ms/step - loss: 0.5504 - accuracy: 0.7216 - val_loss: 0.5294 - val_accuracy: 0.7370
# Epoch 8/60
# 250/250 [==============================] - 54s 217ms/step - loss: 0.5404 - accuracy: 0.7237 - val_loss: 0.5260 - val_accuracy: 0.7435
# Epoch 9/60
# 250/250 [==============================] - 52s 208ms/step - loss: 0.5297 - accuracy: 0.7358 - val_loss: 0.5210 - val_accuracy: 0.7460
# Epoch 10/60
# 250/250 [==============================] - 52s 208ms/step - loss: 0.5189 - accuracy: 0.7436 - val_loss: 0.5116 - val_accuracy: 0.7580
# Epoch 11/60
# 250/250 [==============================] - 54s 217ms/step - loss: 0
60
# 250/250 [==============================] - 54s 217ms/step - loss: 0.4336 - accuracy: 0.7972 - val_loss: 0.4472 - val_accuracy: 0.7900
# Epoch 36/60
# 250/250 [==============================] - 54s 214ms/step - loss: 0.4305 - accuracy: 0.8019 - val_loss: 0.4459 - val_accuracy: 0.7915
# Epoch 37/60
# 250/250 [==============================] - 54s 217ms/step - loss: 0.4344 - accuracy: 0.8012 - val_loss: 0.4402 - val_accuracy: 0.7960
# Epoch 38/60
# 250/250 [==============================] - 52s 209ms/step - loss: 0.4288 - accuracy: 0.7989 - val_loss: 0.4316 - val_accuracy: 0.7995
# Epoch 39/60
# 250/250 [==============================] - 55s 218ms/step - loss: 0.4302 - accuracy: 0.7970 - val_loss: 0.4486 - val_accuracy: 0.8010
# Epoch 40/60
# 250/250 [==============================] - 52s 209ms/step - loss: 0.4302 - accuracy: 0.8016 - val_loss: 0.4488 - val_accuracy: 0.7970
# Epoch 41/60
# 250/250 [==============================] - 52s 208ms/step - loss: 0.4251 - accuracy: 0.7997 - val_loss: 0.4697 - val_accuracy: 0.7795
# Epoch 42/60
# 250/250 [==============================] - 52s 209ms/step - loss: 0.4147 - accuracy: 0.8114 - val_loss: 0.4733 - val_accuracy: 0.7920
# Epoch 43/60
# 250/250 [==============================] - 52s 209ms/step - loss: 0.4215 - accuracy: 0.8074 - val_loss: 0.4278 - val_accuracy: 0.8060
# Epoch 44/60
# 250/250 [==============================] - 54s 217ms/step - loss: 0.4139 - accuracy: 0.8086 - val_loss: 0.4334 - val_accuracy: 0.8050
# Epoch 45/60
# 250/250 [==============================] - 52s 208ms/step - loss: 0.4189 - accuracy: 0.8025 - val_loss: 0.4402 - val_accuracy: 0.8015
# Epoch 46/60
# 250/250 [==============================] - 52s 210ms/step - loss: 0.4183 - accuracy: 0.8076 - val_loss: 0.4462 - val_accuracy: 0.7945
# Epoch 47/60
# 250/250 [==============================] - 52s 209ms/step - loss: 0.4163 - accuracy: 0.8116 - val_loss: 0.4516 - val_accuracy: 0.7960
# Epoch 48/60
# 250/250 [==============================] - 54s 215ms/step - loss: 0.4132 - accuracy: 0.8070 - val_loss: 0.4309 - val_accuracy: 0.7970
# Epoch 49/60
# 250/250 [==============================] - 52s 209ms/step - loss: 0.4197 - accuracy: 0.8040 - val_loss: 0.4390 - val_accuracy: 0.8005
# Epoch 50/60
# 250/250 [==============================] - 53s 211ms/step - loss: 0.4127 - accuracy: 0.8091 - val_loss: 0.4449 - val_accuracy: 0.7995
# Epoch 51/60
# 250/250 [==============================] - 52s 208ms/step - loss: 0.4047 - accuracy: 0.8160 - val_loss: 0.4406 - val_accuracy: 0.8045
# Epoch 52/60
# 250/250 [==============================] - 52s 209ms/step - loss: 0.4146 - accuracy: 0.8067 - val_loss: 0.4301 - val_accuracy: 0.8050
# Epoch 53/60
# 250/250 [==============================] - 52s 208ms/step - loss: 0.4034 - accuracy: 0.8124 - val_loss: 0.4399 - val_accuracy: 0.8015
# Epoch 54/60
# 250/250 [==============================] - 54s 217ms/step - loss: 0.4096 - accuracy: 0.8080 - val_loss: 0.4388 - val_accuracy: 0.7950
# Epoch 55/60
# 250/250 [==============================] - 52s 209ms/step - loss: 0.4105 - accuracy: 0.8081 - val_loss: 0.4402 - val_accuracy: 0.8070
# Epoch 56/60
# 250/250 [==============================] - 53s 213ms/step - loss: 0.4031 - accuracy: 0.8174 - val_loss: 0.4292 - val_accuracy: 0.8040
# Epoch 57/60
# 250/250 [==============================] - 52s 210ms/step - loss: 0.4026 - accuracy: 0.8150 - val_loss: 0.4319 - val_accuracy: 0.8075
# Epoch 58/60
# 250/250 [==============================] - 52s 210ms/step - loss: 0.3975 - accuracy: 0.8179 - val_loss: 0.4467 - val_accuracy: 0.7960
# Epoch 59/60
# 250/250 [==============================] - 54s 218ms/step - loss: 0.4041 - accuracy: 0.8139 - val_loss: 0.4279 - val_accuracy: 0.8025
# Epoch 60/60
# 250/250 [==============================] - 52s 208ms/step - loss: 0.3982 - accuracy: 0.8167 - val_loss: 0.4253 - val_accuracy: 0.8085

# %%
import numpy as np
from keras.preprocessing import image

# %%
test_image = image.load_img('/content/CNN-for-image-Classification/dataset/single_prediction/cat_or_dog_4.jpg', target_size= input_size)
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
# Out:
# 1/1 [==============================] - 0s 98ms/step

# %%
training_set.class_indices
# Out:
# {'cats': 0, 'dogs': 1}

# %%
if result [0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'

# %%
prediction
# Out:
# 'dog'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf

import cv2
import os

import numpy as np

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(60)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
